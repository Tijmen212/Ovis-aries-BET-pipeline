# %% [markdown]
# # Automated pipeline for skullstrip of sheep
# using ANTs, FSL, and nipype

# %% [markdown]
# Outline:
#
# a. generate transformation files <br>
# b. Ants ApplyTransforms to bring the mask into individual sheep space <br>
# c. skull strip with fsl ApplyMask <br>
#
# - Apply steps a - c to all sheep in 'files' folder <br>
# this is achieved with nipype, using MapNodes to iterate steps over each file
#
# 1. Select files from folder (folder needs to contain template and mask as well)
# 2. Configure nodes for registration, tranformation, apply-mask
# 3. Set up a datasink for the resulting skull-stipped files
# 4. Connect the nodes in a workflow and run
#
# you can visualise steps 1-4 in a automated graph.

# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including Nipype, ANTs, and FSL.

# %%
# Import Required Libraries
import nipype.interfaces.ants as ants
import nipype.interfaces.fsl as fsl
from nipype import SelectFiles, Node, MapNode
import nibabel as nib
from nilearn import plotting

# %%
def quick_slice(f_name):
    '''quickly view a file as some slices'''

    plotting.plot_anat(f_name, title='', 
                       display_mode='ortho', 
                       dim=-1,
                       cut_coords=[5,-75,-30], 
                       draw_cross=False, 
                       radiological=True)

# %% [markdown]
# # Select files you want to skullstrip
# using nipype 'SelectFiles' on the directory of interest

# %%
# String template with {}-based strings
templates = {'anat': 'RT*_*_{structural}.nii.gz',
             'template': 'T1_MPRAGE_template0.nii.gz',
             'mask' : 'T1_MPRAGE_template_mask.nii.gz'}

# Create SelectFiles node
sf = Node(SelectFiles(templates), name='selectfiles')

# Location of the dataset folder
sf.inputs.base_directory = '/Users/tijmenvanslageren/Desktop/BET_pipeline/files'

# Feed {}-based placeholder strings with values
sf.inputs.structural = 'T1_MPRAGE'

# %%
sf.run().outputs
# Out:
# 241210-11:44:44,865 nipype.workflow INFO:
# 	 [Node] Setting-up "selectfiles" in "/private/var/folders/hr/60l6nnq51j785m1z1g0w32q00000gp/T/tmpvq1ybc4z/selectfiles".
# 241210-11:44:44,873 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 241210-11:44:44,880 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.001354s.
# anat = ['/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT090_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT090_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT090_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT090_28d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT090_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT095_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT095_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT095_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT095_28d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT095_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT096_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT096_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT096_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT096_28d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT096_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT098_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT098_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT098_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT098_28d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT098_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT099_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT099_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT099_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT099_28d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT099_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT100_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT100_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT100_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT100_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT101_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT101_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT101_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT101_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT102_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT102_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT103_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT103_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT103_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT103_28d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT103_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT104_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT104_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT104_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT104_28d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT104_Pre_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT105_3d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT105_6d_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT105_24h_T1_MPRAGE.nii.gz', '/Users/tijmenvanslageren/Desktop/BET_pipeline/files/RT105_28d_T1_MPRAGE.nii ...
# mask = /Users/tijmenvanslageren/Desktop/BET_pipeline/files/T1_MPRAGE_template_mask.nii.gz
# template = /Users/tijmenvanslageren/Desktop/BET_pipeline/files/T1_MPRAGE_template0.nii.gz

# %% [markdown]
# # Configure ANTs quick Registration
# to produce the neccessary GenericAffine and Warp files.

# %%
from nipype.interfaces.ants import RegistrationSynQuick

# registration iterating over the 'moving image' with the list from sf

regSyn = MapNode(RegistrationSynQuick(),
                 iterfield=['moving_image'],
                 dimension=3, 
                 name= 'Registration_SynQuick')

# %% [markdown]
# # Apply tranformation to mask
# bring the mask into individual sheep space with inverse transform and inverse warp

# %%
# import the ants 'apply transforms' module
from nipype.interfaces.ants import ApplyTransforms

# Assign the ApplyTransforms module to 'at'
# interate the reference and transforms (NOT input_file, as this is always mask)
at = MapNode(ApplyTransforms(), name='ApplyTransforms', 
           iterfield=['reference_image', 
                      'transforms'])

at.inputs.dimension = 3

# invert the out_matrix from regSyn? - Yes
at.inputs.invert_transform_flags = [True]

# specify multilabel cost function
at.inputs.interpolation = 'MultiLabel'

# %% [markdown]
# # Configure FSL ApplyMask
# Apply the mask from the template to the inverse warped sheep.

# %%
# import relevant module from fsl maths
from nipype.interfaces.fsl import maths

bet1 = MapNode(maths.ApplyMask(), 
               iterfield=['in_file',
                          'mask_file'],
               out_file = '*.brain.nii.gz',
               name= 'BrainExtraction')

# %% [markdown]
# # Set up the datasink
# and configure the output to be resticted to just files we're interested in

# %%
from nipype.interfaces.io import DataSink

# Create DataSink object
sinker = Node(DataSink(), name='sink')

# Name of the output folder
sinker.inputs.base_directory = '/Users/tijmenvanslageren/Desktop/BET_pipeline/sink'

# %% [markdown]
# # Set up workflow
# set up the skullstrip workflow

# %%
from nipype import Workflow

wf = Workflow(name='test_sf_to_sink', 
              base_dir='/Users/tijmenvanslageren/Desktop/BET_pipeline/test_workflow')

wf.connect([(sf, regSyn,     [("template", "fixed_image"),
                              ("anat", "moving_image")]),
            (sf, at,         [("mask", "input_image")]),
            (regSyn, at,     [("inverse_warped_image", "reference_image"),
                              ("out_matrix", "transforms")]),
            (at, bet1,       [("output_image", "mask_file")]),
            (sf, bet1,       [("anat", "in_file")]),
            (bet1, sinker,   [("out_file", "in_file")])
            ])
# wf.run() comment out - takes 4.05 hours to run on 100 volumes

# %% [markdown]
# # Visualise workflow
# as an acyclic graph

# %%
wf.write_graph(graph2use='orig', dotfilename='./graph.dot')
from IPython.display import Image
Image(filename="/Users/tijmenvanslageren/Desktop/BET_pipeline/graph_detailed.png")
# Out:
# 241210-11:44:47,661 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/tijmenvanslageren/Desktop/BET_pipeline/graph.png (graph2use=orig, simple_form=True).

# %% [markdown]
# # Plot the results
# skullstripped data in matplotlib

# %%
# import libraries
import os
import nibabel as nib
import matplotlib.pyplot as plt

# Define the base directory and file pattern
base_dir = '/Users/tijmenvanslageren/Desktop/BET_pipeline/sink'
file_pattern = '_BrainExtraction*/RT*_T1_MPRAGE_masked.nii.gz'

# Get the list of files (just pre-surgery in this case)
file_paths = []
for root, dirs, files in os.walk(base_dir):
    for file in files: 
        #  erase 'Pre' here to grab ALL the skullstripped files
        if file.endswith('Pre_T1_MPRAGE_masked.nii.gz'): 
            file_paths.append(os.path.join(root, file)) 

# Ensure we have exactly 21 files
print(len(file_paths))
# Out:
# 21

# %% [markdown]
# note 21 'Pre' surgery files are retrived

# %% [markdown]
# Inspect result

# %%
'''Comment on result : all 99 volumes have been skullstripped. Here the 21
pre surgery sheep are displayed these sagittal sections indicate a good result'''

# Load and plot the files
for i, file_path in enumerate(file_paths):
    # Load the file with nibabel
    img = nib.load(file_path)
    data = img.get_fdata()

    # Plot a slice
    plt.figure(figsize=(4, 4))
    plt.imshow(data[ 45 , :, :], cmap='gray')
    plt.title(f'File {i+1}: {os.path.basename(file_path)}')
    plt.axis('off')
    plt.tight_layout
# Out:
# /var/folders/hr/60l6nnq51j785m1z1g0w32q00000gp/T/ipykernel_31336/2400774170.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(4, 4))

# %% [markdown]
# # END
